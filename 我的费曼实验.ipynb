# %% [markdown]
# ## 📝 知识点：[在这里写下概念名称]
# > **目标：** 用 8 岁小孩能听懂的话解释它。
#
# ### 1. 我的第一版解释（费曼第一步）
# [在这里写下你现在的理解...]
#
# ### 2. AI 纠错（NotebookLM 联动）
# - 将上面的解释复制给 NotebookLM。
# - 问它：“我讲得哪里不清楚？请给我 3 个挑战性问题。”
# - 把 AI 的反馈粘贴在这里。
#
# ### 3. 最终简化版
# [经过 AI 蹂躏后，你最终形成的“人话”解释。]
